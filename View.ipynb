# %%
try:
    # !python main.py
except:
    # !virtualenv venv
    # !source venv/bin/activate
    # !pip install -r requiriments.txt
    # !python main.py
# Out:
# sh: 1: scrapy: not found
# Traceback (most recent call last):
#   File "main.py", line 34, in <module>
#     m.main()
#   File "main.py", line 11, in main
#     file = open(file_name, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'government_alms.json'

# %%
from util.plot import Plot

import pandas as pd
data = pd.read_json('./api.json')

plt = Plot(data)

# %%
plt.plot_timeline('BAHIA', 2004, 2007)
# Out:
# O crescimento médio anual dos gastos neste período de tempo foi: 1005690721.75

# %%
plt.plot_state_year('SERGIPE', 2007)
# Out:
# O gasto foi de 167301935 no ano de 2007

# %%
plt.verify_mean('BAHIA', 'ESP\u00cdRITO SANTO', 2004, 2007)

# %%
plt.plot_only_out('SÃO PAULO')
# Out:
# Quantidade de valores gastos com os favorecidos no estado de SÃO PAULO no período de 2004 a 2017

# %%
plt.plot_total()
